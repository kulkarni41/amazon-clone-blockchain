# %% [markdown]
# <a href="https://colab.research.google.com/github/kulkarni41/amazon-clone-blockchain/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://pandas.pydata.org/docs/user_guide/10min.html

import numpy as np
import pandas as pd
#Seties - One dimentioinal labeled array
s = pd.Series([1,3,np.nan,6,7])
s
#DataFrame: a two-dimensional data structure that holds data like a two-dimension array or a table with rows and columns.
dates=pd.date_range('20230101',periods=6)
dates
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2023-01-01  0.695412 -0.136965 -1.067723 -2.389216
# 2023-01-02 -0.236254 -0.944939 -0.104566  1.154044
# 2023-01-03  0.659461  1.550689 -0.173707  0.021102
# 2023-01-04  0.359862  0.639665  0.165217  0.991019
# 2023-01-05 -0.676455  0.346341 -0.225640  0.137608
# 2023-01-06 -0.196236  1.194124  3.122201  0.329499

# %%
df2=pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20230102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
#df2.dtypes
# Out:
#      A          B    C  D      E    F
# 0  1.0 2023-01-02  1.0  3   test  foo
# 1  1.0 2023-01-02  1.0  3  train  foo
# 2  1.0 2023-01-02  1.0  3   test  foo
# 3  1.0 2023-01-02  1.0  3  train  foo

# %%
#Viewing Dara
df2.head()
df2.tail(3)
df2.index
df2.columns
df2.to_numpy() #Convert to Array
df.describe()
df.T  #Transpose of df
df2.dtypes
df.sort_index(axis=1,ascending=False,)
df.sort_values(by="B",ascending=False)
# Out:
#                    A         B         C         D
# 2023-01-03  0.659461  1.550689 -0.173707  0.021102
# 2023-01-06 -0.196236  1.194124  3.122201  0.329499
# 2023-01-04  0.359862  0.639665  0.165217  0.991019
# 2023-01-05 -0.676455  0.346341 -0.225640  0.137608
# 2023-01-01  0.695412 -0.136965 -1.067723 -2.389216
# 2023-01-02 -0.236254 -0.944939 -0.104566  1.154044

# %%
#Getting Iteam
df["A"]
df[0:2]
df["20230102":"20230105"]
df[["A","C"]]
df.loc["20230103","B"]
df.loc[:,["A","B"]]
df.loc["20230102":"20230104",["A","B"]]
df.loc["20230102"]
df.loc[dates[0]] #indexed 0
df.loc[df["A"]<0, ["A","B"]]
# Out:
#                    A         B
# 2023-01-02 -0.236254 -0.944939
# 2023-01-05 -0.676455  0.346341
# 2023-01-06 -0.196236  1.194124

# %%
#iloc integer-location-based indexing
df.iloc[1,1]
df.iloc[0]
df.iloc[3:5,0:2] #3:5 - it includes 3 & exclude 5 & in 0:2 as well 2 which is column C is excluded (stop index is excluded from the selection.)
df.iloc[[1,2,4],[0,2]]
df.iloc[1:3,:]
df.iloc[:,1:3]
# Out:
#                    B         C
# 2023-01-01 -0.136965 -1.067723
# 2023-01-02 -0.944939 -0.104566
# 2023-01-03  1.550689 -0.173707
# 2023-01-04  0.639665  0.165217
# 2023-01-05  0.346341 -0.225640
# 2023-01-06  1.194124  3.122201

# %%
df[df["A"]>0]
df[df >0]
df3=df.copy()
df3["E"]=["One Jan","Two Jan","Three Jan","Four Jan","Five Jan","Six Jan"]
df3["F"]=[1,2,3,4,5,6]
df3
df3[df3['E'].isin(["Two Jan","Four Jan"])]
# Out:
#                    A         B         C         D         E  F
# 2023-01-02 -0.236254 -0.944939 -0.104566  1.154044   Two Jan  2
# 2023-01-04  0.359862  0.639665  0.165217  0.991019  Four Jan  4

# %%
s1=pd.Series([1,2,3,4,5,6],index=pd.date_range("20230102",periods=6))
s1
df["F"]=s1
df
# Out:
#                    A         B         C         D    F
# 2023-01-01  0.695412 -0.136965 -1.067723 -2.389216  NaN
# 2023-01-02 -0.236254 -0.944939 -0.104566  1.154044  1.0
# 2023-01-03  0.659461  1.550689 -0.173707  0.021102  2.0
# 2023-01-04  0.359862  0.639665  0.165217  0.991019  3.0
# 2023-01-05 -0.676455  0.346341 -0.225640  0.137608  4.0
# 2023-01-06 -0.196236  1.194124  3.122201  0.329499  5.0

# %%
df.at[dates[0],"A"]=0
df.iat[0,1]=0
df
# Out:
#                    A         B         C         D    F
# 2023-01-01  0.000000  0.000000 -1.067723 -2.389216  NaN
# 2023-01-02 -0.236254 -0.944939 -0.104566  1.154044  1.0
# 2023-01-03  0.659461  1.550689 -0.173707  0.021102  2.0
# 2023-01-04  0.359862  0.639665  0.165217  0.991019  3.0
# 2023-01-05 -0.676455  0.346341 -0.225640  0.137608  4.0
# 2023-01-06 -0.196236  1.194124  3.122201  0.329499  5.0

# %%
len(df)
# Out:
# 6
